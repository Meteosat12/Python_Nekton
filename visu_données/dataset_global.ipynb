# %%
import numpy as np
import pandas as pd
import xarray as xr
from pathlib import Path
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import sys

# %% [markdown]
# ## Mise en forme des données en dataset

# %% [markdown]
# On définit les chemins et les paramètres

# %%
provinces_folder = Path("/data/rd_exchange/asauvebois/dataset_biome") # est-ce que je le mets dans la boucle ou est-ce que je crée des dossiers avec l'ajout du biome ?
micronekton_folder = Path("/data/rd_exchange/asauvebois/moy_month")

variables_mnkc= ["mnkc_epi", "mnkc_umeso", "mnkc_lmeso", "mnkc_mumeso", "mnkc_mlmeso", "mnkc_hmlmeso"]


rows = []

# %% [markdown]
# Création du Dataset

# %%
for mnkc_file in sorted(micronekton_folder.glob("*_monthly_mean.nc")):

#on va extraire l'année et le mois depuis le nom du fichier
    year_str = mnkc_file.stem.split("_")[0]
    month_str = mnkc_file.stem.split("_")[1]
    print(f"\nTraitement {year_str}-{month_str}...")


#Fichier province correspondant

    prov_file = provinces_folder/f"provinces_Y{year_str}_M{month_str}.nc"

    if not prov_file.exists():
        print(f"   → Province manquante, on passe")
        continue

#on charge les deux datasets

    ds_mnkc = xr.open_dataset(mnkc_file)
    ds_prov = xr.open_dataset(prov_file)
    
    provinces = ds_prov["province"].values
    prov_list = list(set(provinces.flatten()))

#on boucle sur les provinces 
    prov_list = [p for p in set(provinces.flatten()) if not np.isnan(p)]

    for prov_id in prov_list:
        mask = (provinces == prov_id) #true si on est dans cette province
        biome_values = ds_prov["Biome"].values[mask]
        if len(biome_values) == 0:
            continue
        biome_id = ds_prov["Biome"].values[mask][0] #on prend toutes les valeurs de biome où le masque est true, et on prend la première car toutes les cases d'une même province ont le même biome
       
        row = {
            "date": f"{year_str}-{month_str}",
            "prov": prov_id,
            "Biome": biome_id
        }

#Puis on fait la moyenne spatiale de chaque variable sur la province

        for var in variables_mnkc:
            valeur = ds_mnkc[var].where(mask).mean().values
            row[var] = float(valeur)

        rows.append(row)


    ds_mnkc.close()
    ds_prov.close()


#création du Dataset
df = pd.DataFrame(rows)
df = df.set_index('date')
print(df)
# Out:
# Traitement 1998-01...
#
# Traitement 1998-02...
#
# Traitement 1998-03...
#
# Traitement 1998-04...
#
# Traitement 1998-05...
#
# Traitement 1998-06...
#
# Traitement 1998-07...
#
# Traitement 1998-08...
#
# Traitement 1998-09...
#
# Traitement 1998-10...
#
# Traitement 1998-11...
#
# Traitement 1998-12...
#
# Traitement 1999-01...
#
# Traitement 1999-02...
#
# Traitement 1999-03...
#
# Traitement 1999-04...
#
# Traitement 1999-05...
#
# Traitement 1999-06...
#
# Traitement 1999-07...
#
# Traitement 1999-08...
#
# Traitement 1999-09...
#
# Traitement 1999-10...
#
# Traitement 1999-11...
#
# Traitement 1999-12...
#
# Traitement 2000-01...
#
# Traitement 2000-02...
#
# Traitement 2000-03...
#
# Traitement 2000-04...
#
# Traitement 2000-05...
#
# Traitement 2000-06...
#
# Traitement 2000-07...
#
# Traitement 2000-08...
#
# Traitement 2000-09...
#
# Traitement 2000-10...
#
# Traitement 2000-11...
#
# Traitement 2000-12...
#
# Traitement 2001-01...
#
# Traitement 2001-02...
#
# Traitement 2001-03...
#
# Traitement 2001-04...
#
# Traitement 2001-05...
#
# Traitement 2001-06...
#
# Traitement 2001-07...
#
# Traitement 2001-08...
#
# Traitement 2001-09...
#
# Traitement 2001-10...
#
# Traitement 2001-11...
#
# Traitement 2001-12...
#
# Traitement 2002-01...
#
# Traitement 2002-02...
#
# Traitement 2002-03...
#
# Traitement 2002-04...
#
# Traitement 2002-05...
#
# Traitement 2002-06...
#
# Traitement 2002-07...
#
# Traitement 2002-08...
#
# Traitement 2002-09...
#
# Traitement 2002-10...
#
# Traitement 2002-11...
#
# Traitement 2002-12...
#
# Traitement 2003-01...
#
# Traitement 2003-02...
#
# Traitement 2003-03...
#
# Traitement 2003-04...
#
# Traitement 2003-05...
#
# Traitement 2003-06...
#
# Traitement 2003-07...
#
# Traitement 2003-08...
#
# Traitement 2003-09...
#
# Traitement 2003-10...
#
# Traitement 2003-11...
#
# Traitement 2003-12...
#
# Traitement 2004-01...
#
# Traitement 2004-02...
#
# Traitement 2004-03...
#
# Traitement 2004-04...
#
# Traitement 2004-05...
#
# Traitement 2004-06...
#
# Traitement 2004-07...
#
# Traitement 2004-08...
#
# Traitement 2004-09...
#
# Traitement 2004-10...
#
# Traitement 2004-11...
#
# Traitement 2004-12...
#
# Traitement 2005-01...
#
# Traitement 2005-02...
#
# Traitement 2005-03...
#
# Traitement 2005-04...
#
# Traitement 2005-05...
#
# Traitement 2005-06...
#
# Traitement 2005-07...
#
# Traitement 2005-08...
#
# Traitement 2005-09...
#
# Traitement 2005-10...
#
# Traitement 2005-11...
#
# Traitement 2005-12...
#
# Traitement 2006-01...
#
# Traitement 2006-02...
#
# Traitement 2006-03...
#
# Traitement 2006-04...
#
# Traitement 2006-05...
#
# Traitement 2006-06...
#
# Traitement 2006-07...
#
# Traitement 2006-08...
#
# Traitement 2006-09...
#
# Traitement 2006-10...
#
# Traitement 2006-11...
#
# Traitement 2006-12...
#
# Traitement 2007-01...
#
# Traitement 2007-02...
#
# Traitement 2007-03...
#
# Traitement 2007-04...
#
# Traitement 2007-05...
#
# Traitement 2007-06...
#
# Traitement 2007-07...
#
# Traitement 2007-08...
#
# Traitement 2007-09...
#
# Traitement 2007-10...
#
# Traitement 2007-11...
#
# Traitement 2007-12...
#
# Traitement 2008-01...
#
# Traitement 2008-02...
#
# Traitement 2008-03...
#
# Traitement 2008-04...
#
# Traitement 2008-05...
#
# Traitement 2008-06...
#
# Traitement 2008-07...
#
# Traitement 2008-08...
#
# Traitement 2008-09...
#
# Traitement 2008-10...
#
# Traitement 2008-11...
#
# Traitement 2008-12...
#
# Traitement 2009-01...
#
# Traitement 2009-02...
#
# Traitement 2009-03...
#
# Traitement 2009-04...
#
# Traitement 2009-05...
#
# Traitement 2009-06...
#
# Traitement 2009-07...
#
# Traitement 2009-08...
#
# Traitement 2009-09...
#
# Traitement 2009-10...
#
# Traitement 2009-11...
#
# Traitement 2009-12...
#
# Traitement 2010-01...
#
# Traitement 2010-02...
#
# Traitement 2010-03...
#
# Traitement 2010-04...
#
# Traitement 2010-05...
#
# Traitement 2010-06...
#
# Traitement 2010-07...
#
# Traitement 2010-08...
#
# Traitement 2010-09...
#
# Traitement 2010-10...
#
# Traitement 2010-11...
#
# Traitement 2010-12...
#
# Traitement 2011-01...
#
# Traitement 2011-02...
#
# Traitement 2011-03...
#
# Traitement 2011-04...
#
# Traitement 2011-05...
#
# Traitement 2011-06...
#
# Traitement 2011-07...
#
# Traitement 2011-08...
#
# Traitement 2011-09...
#
# Traitement 2011-10...
#
# Traitement 2011-11...
#
# Traitement 2011-12...
#
# Traitement 2012-01...
#
# Traitement 2012-02...
#
# Traitement 2012-03...
#
# Traitement 2012-04...
#
# Traitement 2012-05...
#
# Traitement 2012-06...
#
# Traitement 2012-07...
#
# Traitement 2012-08...
#
# Traitement 2012-09...
#
# Traitement 2012-10...
#
# Traitement 2012-11...
#
# Traitement 2012-12...
#
# Traitement 2013-01...
#
# Traitement 2013-02...
#
# Traitement 2013-03...
#
# Traitement 2013-04...
#
# Traitement 2013-05...
#
# Traitement 2013-06...
#
# Traitement 2013-07...
#
# Traitement 2013-08...
#
# Traitement 2013-09...
#
# Traitement 2013-10...
#
# Traitement 2013-11...
#
# Traitement 2013-12...
#
# Traitement 2014-01...
#
# Traitement 2014-02...
#
# Traitement 2014-03...
#
# Traitement 2014-04...
#
# Traitement 2014-05...
#
# Traitement 2014-06...
#
# Traitement 2014-07...
#
# Traitement 2014-08...
#
# Traitement 2014-09...
#
# Traitement 2014-10...
#
# Traitement 2014-11...
#
# Traitement 2014-12...
#
# Traitement 2015-01...
#
# Traitement 2015-02...
#
# Traitement 2015-03...
#
# Traitement 2015-04...
#
# Traitement 2015-05...
#
# Traitement 2015-06...
#
# Traitement 2015-07...
#
# Traitement 2015-08...
#
# Traitement 2015-09...
#
# Traitement 2015-10...
#
# Traitement 2015-11...
#
# Traitement 2015-12...
#
# Traitement 2016-01...
#
# Traitement 2016-02...
#
# Traitement 2016-03...
#
# Traitement 2016-04...
#
# Traitement 2016-05...
#
# Traitement 2016-06...
#
# Traitement 2016-07...
#
# Traitement 2016-08...
#
# Traitement 2016-09...
#
# Traitement 2016-10...
#
# Traitement 2016-11...
#
# Traitement 2016-12...
#
# Traitement 2017-01...
#
# Traitement 2017-02...
#
# Traitement 2017-03...
#
# Traitement 2017-04...

# %%
df.to_csv("/data/rd_exchange/asauvebois/df_micronekton_.csv")

# %% [markdown]
# Pour recharger le csv

# %%
df = pd.read_csv("/data/rd_exchange/asauvebois/dataset_global/df_micronekton.csv", index_col='date')
print(df)
# Out:
#           prov  Biome  mnkc_epi  mnkc_umeso  mnkc_lmeso  mnkc_mumeso  \
# date
# 1998-01  101.0    1.0  0.460964    0.614274    2.413278     0.796105
# 1998-01  102.0    1.0  0.372419    0.556480    2.125784     0.659933
# 1998-01  103.0    1.0  0.422545    0.630010    2.017993     0.685877
# 1998-01  201.0    2.0  1.673023    1.051175    3.281833     1.990258
# 1998-01  202.0    2.0  0.597547    0.426892    1.545762     0.668636
# ...        ...    ...       ...         ...         ...          ...
# 2023-12  503.0    5.0  1.108908    1.170073    2.385936     1.670662
# 2023-12  502.0    5.0  2.671085    1.872016    4.097959     2.930487
# 2023-12  601.0    6.0  0.689516    1.208844    2.158436     1.199348
# 2023-12  602.0    6.0  2.949227    2.863782    4.445053     3.505710
# 2023-12  603.0    6.0  7.217309    0.850936    0.932081     1.152758
#
#          mnkc_mlmeso  mnkc_hmlmeso
# date
# 1998-01     1.066693      1.017023
# 1998-01     0.967965      0.805726
# 1998-01     1.008636      0.814236
# 1998-01     1.617703      2.195934
# 1998-01     0.711194      0.787883
# ...              ...           ...
# 2023-12     1.579844      1.647481
# 2023-12     2.639450      3.021372
# 2023-12     1.524684      1.039125
# 2023-12     3.011778      2.888916
# 2023-12     0.741526      0.906975
#
# [8665 rows x 8 columns]

# %% [markdown]
# ## Analyse des données CSV

# %% [markdown]
# Avec Ncview, on voit bien que les moyennes caclulées sont cohérentes par rapport aux données mensuelles de biomasse par province.
